# %%
from embedder import Embedder

embed = Embedder()

# %%
from ingest import load_faq_data

documents = load_faq_data()

# %%
texts = [doc["question"] + " " + doc["answer"] for doc in documents]

batch_size = 50
X = []

from tqdm.auto import tqdm
for i in tqdm(range(0, len(texts), batch_size)):
    batch = texts[i:i + batch_size]
    batch_vectors = embed.encode_batch(batch)
    X.extend(batch_vectors)

import numpy as np
X = np.array(X)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]

# %%
query = "Can I still join the course after the start date?"
v_query = embed.encode(query)

scores = X.dot(v_query)
idx = np.argmax(scores)

documents[idx]
# Out:
# {'course': 'data-engineering-zoomcamp',
#  'section': 'General Course-Related Questions',
#  'question': 'Course: Can I still join the course after the start date?',
#  'answer': "Yes, even if you don't register, you're still eligible to submit the homework.\n\nBe aware, however, that there will be deadlines for turning in homeworks and the final projects. So don't leave everything for the last minute.",
#  'doc_id': '3f1424af17'}

# %%
embed = Embedder("models/Xenova/bge-base-en-v1.5")
vectors = embed.encode(query)
print(vectors.shape)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 embed = Embedder("models/Xenova/bge-base-en-v1.5")
#       2 vectors = embed.encode(query)
#       3 print(vectors.shape)
#
# File /media/bsh/0667a20f-7143-4a55-90cf-b3dc1ae94d49/bahar/Documents/Projects/python/llm-zoomcamp-homework/embedder.py:10, in Embedder.__init__(self, path)
#       8 def __init__(self, path="models/Xenova/all-MiniLM-L6-v2"):
#       9     path = Path(path)
# ---> 10     self.tokenizer = Tokenizer.from_file(str(path / "tokenizer.json"))
#      11     self.session = ort.InferenceSession(
#      12         str(path / "model.onnx"), providers=["CPUExecutionProvider"]
#      13     )
#      14     self.input_names = {inp.name for inp in self.session.get_inputs()}
#
# Exception: No such file or directory (os error 2)
